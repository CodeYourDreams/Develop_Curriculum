# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("../housing_data.csv")

# %% [markdown]
# - line graph -- price related to age
# - bar plot -- price related to number of bedrooms
# - histograms -- number of houses with x property
# - scatterplot -- price related to year built

# %%
fig, ax = plt.subplots()

ax.scatter(data["yr_built"], data["price"])

# %%
price_by_yr = data[["yr_built","price"]].groupby("yr_built").mean()
price_by_yr
# Out:
#                   price
# yr_built
# 1900      581387.206897
# 1901      556935.931034
# 1902      673007.407407
# 1903      480958.195652
# 1904      583756.644444
# 1905      752977.986486
# 1906      669799.402174
# 1907      676257.246154
# 1908      564348.686047
# 1909      696135.159574
# 1910      671536.313433
# 1911      632488.356164
# 1912      612990.696203
# 1913      585683.220339
# 1914      615153.481481
# 1915      584896.296875
# 1916      600915.037975
# 1917      528108.928571
# 1918      492246.875000
# 1919      537779.602273
# 1920      477804.397959
# 1921      613204.473684
# 1922      569688.884211
# 1923      618475.202381
# 1924      570391.151079
# 1925      607219.393939
# 1926      625315.600000
# 1927      653921.600000
# 1928      621713.849206
# 1929      574335.438596
# ...                 ...
# 1986      476953.488372
# 1987      517553.955782
# 1988      583860.029630
# 1989      582961.679310
# 1990      563966.009375
# 1991      630440.915179
# ...

# %%
price_by_yr.plot.line()

# %%
price_by_yr_med = data[["yr_built","price"]].groupby("yr_built").median()
price_by_yr = price_by_yr.rename(columns={'price':'mean'})
price_by_yr_med = price_by_yr_med.rename(columns={'price':'median'})
plot_data = pd.concat([price_by_yr, price_by_yr_med], axis=1)
plot_data.plot.line()

# %%
price_by_num_rooms = data[["bedrooms","price"]].groupby("bedrooms").mean()

# %%
price_by_num_rooms.plot.bar()

# %%
price_by_waterfront = data[["waterfront","price"]].groupby("waterfront").mean()
price_by_waterfront.plot.bar()

# %%
data["bathrooms"].plot.hist(bins=10)

# %% [markdown]
# # TODO: Matplotlib and plot styling
